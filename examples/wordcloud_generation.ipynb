# %% [markdown]
# # Word Cloud Generation
# This notebook demonstrates how to generate a word cloud using the `wordcloud` library based on a provided list of phrases.

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# ## Input Text
# Define the text from which the word cloud will be generated.

# %%
# Provided text content
text = '''
BioImage-Analysis Code Generation
Introduction to CellProfiler: A beginner’s guide to segmentation
Napari meets Cellpose: Developing Workflows for Finetuning Biological Instance Segmentation Models
Introducing napari ndev: a plugin for generalizable start-to-finish batch analysis without code
Interactive phasor analysis of FLIM data using FLUTE
Jupyter Notebooks and Napari Widgets for SAM, Cellpose, Stardist and friends
Introduction to Fiji / ImageJ
TrackMate-Lacss: A plugin for 2D or 3D single-cell segmentation with time-lapse capabilities in a server/client model.
Connecting CellProfiler to ilastik and Cellpose
Object tracking and track analysis using TrackMate and CellTracksColab
3D Segmentation using CellProfiler
Image Analysis Ask Me Anything
Scalable Interactive Visualizations and AI-based Image Processing in the WIPP Image Analytics Platform
QuPath for Fiji Fans
Segmentation & Scripting with Fiji / ImageJ
Piximi: Installation-free Segmentation and Classification in the Browser
QuPath for Beginners
Browsing, Filtering, and Downloading Data in the Cell Painting Gallery
SAMJ: Fast annotation with foundation models on Java-based Bioimage Platforms
PhasorPy: an open-source Python library for the analysis of fluorescence lifetime and hyperspectral images using the phasor approach
Fine tuning deep-learning models with the active-learning plugin for Napari
Single-cell segmentation, tracking, annotation, and quantification with Cell-ACDC
Mastering Mastodon: Tracking, Analyzing, and Visualizing Inside Large Biological 3D Timelapse Datasets
Deep-Learning for Image Classification: Model Optimization and Visualization
clEsperanto: GPU-accelerated Image Processing Library
QuPath for Python Programmers
Unlock the Potential of Your Microscopy Images with Morpheus Software!
Using Fiji from Python based software
multiview-stitcher: image registration and fusion in python and napari
Introducing InstanSeg, a deep-learning based method for the segmentation of cells in brightfield and fluorescence images
Deep-Learning for Microscopy
ezomero - making your OMERO life easier
Versatile Deep-Learning for 2D and 3D Bioimage-Analysis with CytoDL
'''

# %% [markdown]
# ## Generate Word Cloud
# Create and visualize the word cloud from the provided text.

# %%
# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Provided Text')
plt.show()

# %% [markdown]
# ## Save Word Cloud
# Save the generated word cloud image for later use.

# %%
# Save the word cloud as a .png file
wordcloud.to_file('wordcloud_output.png')
